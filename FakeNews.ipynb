# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanth654/fake_news/blob/main/FakeNews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
true_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/True.csv')
fake_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Fake.csv')

# %%
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_df['label']=1
fake_df['label']=0

# %%
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news=pd.concat([true_df,fake_df],axis=0)
news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news.tail()
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date  label
# 23476  January 16, 2016      0
# 23477  January 16, 2016      0
# 23478  January 15, 2016      0
# 23479  January 14, 2016      0
# 23480  January 12, 2016      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=news.drop(['title','subject','date'],axis=1)
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      1
# 1  WASHINGTON (Reuters) - Transgender people will...      1
# 2  WASHINGTON (Reuters) - The special counsel inv...      1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      1

# %%
news=news.sample(frac=1)
news.head()
# Out:
#                                                     text  label
# 15565  ANKARA (Reuters) - Turkey will resume processi...      1
# 2263   BRIDGEWATER, N.J. (Reuters) - President Donald...      1
# 12030  DHAKA (Reuters) - Hundreds of people rushed to...      1
# 22734  Tune in to the Alternate Current Radio Network...      0
# 589    WASHINGTON (Reuters) - In a move certain to pl...      1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  15565  ANKARA (Reuters) - Turkey will resume processi...      1
# 1   2263  BRIDGEWATER, N.J. (Reuters) - President Donald...      1
# 2  12030  DHAKA (Reuters) - Hundreds of people rushed to...      1
# 3  22734  Tune in to the Alternate Current Radio Network...      0
# 4    589  WASHINGTON (Reuters) - In a move certain to pl...      1

# %%
news=news.drop(['index'],axis=1)
news.head()
# Out:
#                                                 text  label
# 0  ANKARA (Reuters) - Turkey will resume processi...      1
# 1  BRIDGEWATER, N.J. (Reuters) - President Donald...      1
# 2  DHAKA (Reuters) - Hundreds of people rushed to...      1
# 3  Tune in to the Alternate Current Radio Network...      0
# 4  WASHINGTON (Reuters) - In a move certain to pl...      1

# %%
def wordopt(text):
  text=text.lower()
  text=re.sub(r'<.*?>',' ',text)
  text=re.sub(r'http?://\S+|www\.\S+',' ',text)
  text=re.sub(r'[^\w\s]', ' ', text)
  text=re.sub(r'\d',' ',text)
  text=re.sub(r'\n',' ',text)
  return text

# %%
news['text']=news['text'].apply(wordopt)
news['text']
# Out:
# 0        ankara  reuters    turkey will resume processi...
# 1        bridgewater  n j   reuters    president donald...
# 2        dhaka  reuters    hundreds of people rushed to...
# 3        tune in to the alternate current radio network...
# 4        washington  reuters    in a move certain to pl...
#                                ...
# 44893    the white house is beginning to panic  at leas...
# 44894    ulaanbaatar  reuters    mongolia s parliament ...
# 44895    tune in to the alternate current radio network...
# 44896     reuters    highlights of the day for u s  pre...
# 44897    washington  reuters    u s  representative ada...
# Name: text, Length: 44898, dtype: object

# %%
x=news['text']
y=news['label']

# %%
x
# Out:
# 0        ankara  reuters    turkey will resume processi...
# 1        bridgewater  n j   reuters    president donald...
# 2        dhaka  reuters    hundreds of people rushed to...
# 3        tune in to the alternate current radio network...
# 4        washington  reuters    in a move certain to pl...
#                                ...
# 44893    the white house is beginning to panic  at leas...
# 44894    ulaanbaatar  reuters    mongolia s parliament ...
# 44895    tune in to the alternate current radio network...
# 44896     reuters    highlights of the day for u s  pre...
# 44897    washington  reuters    u s  representative ada...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 44893    0
# 44894    1
# 44895    0
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train.shape
# Out:
# (33673,)

# %%
x_test.shape
# Out:
# (11225,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer()
xv_train=vectorizer.fit_transform(x_train)
xv_test=vectorizer.transform(x_test)

# %%
xv_train
# Out:
# <33673x102331 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6911605 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <11225x102331 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2307270 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9862806236080178

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5861
#            1       0.98      0.99      0.99      5364
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
from sklearn.tree import DecisionTreeClassifier
DTC=DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc=DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.9956347438752784

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5861
#            1       1.00      0.99      1.00      5364
#
#     accuracy                           1.00     11225
#    macro avg       1.00      1.00      1.00     11225
# weighted avg       1.00      1.00      1.00     11225

# %%
from sklearn.ensemble import RandomForestClassifier
RFC=RandomForestClassifier()

# %%
RFC.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc=RFC.predict(xv_test)

# %%
RFC.score(xv_test,y_test)
# Out:
# 0.9884187082405346

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5861
#            1       0.99      0.99      0.99      5364
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
def output(n):
  if n==0:
    return 'It is a Fake News'
  elif n==1:
    return 'It is a Real News'

# %%
def manual_testing(news):
  testing_news={"text":[news]}
  new_def_test=pd.DataFrame(testing_news)
  new_def_test["text"]=new_def_test["text"].apply(wordopt)
  new_x_test=new_def_test["text"]
  new_xv_test=vectorizer.transform(new_x_test)
  pred_lr=LR.predict(new_xv_test)
  pred_dtc=DTC.predict(new_xv_test)
  pred_rfc=RFC.predict(new_xv_test)
  return "LR Prediction: {} DTC Prediction: {} RFC Prediction: {}".format(output(pred_lr[0]),output(pred_dtc[0]),output(pred_rfc[0]))

# %%
news_article=str(input("Enter an article"))
manual_testing(news_article)
# Out:
# Enter an articlefghjkl
# 'LR Prediction: It is a Fake News DTC Prediction: It is a Fake News RFC Prediction: It is a Fake News'
